# %% [markdown]
# # Project Title
#
# ## Subtitle
#
# **Author:** Name
# **Course:** ENGR 2451 / DSCI 451
# **Date:** YYYY-MM-DD
#
# > Replace the placeholder text throughout this notebook with your own project content. Remove instructional notes before submitting the final report.

# %% [markdown]
# # Guides for Writing Your Report
#
# For the full document:
#
# - You are writing a **comprehensive report**.
# - The goal is to communicate your analysis to others.
# - Focus on clear communication, not merely on showing code.
# - Keep all code and discussion under the appropriate headings.
# - Delete or remove unused notes and exploratory clutter before final submission.
# - Reference figures, tables, and equations in the narrative.
# - Use captions/titles on all figures and tables.
# - Think about your audience and what they need to understand the analysis.
#
# For progress updates:
#
# - Include previous updates in each submitted update document so progress can be evaluated over time.
# - For the final report, remove the update sections and present a single coherent report.
# - Remove instructional notes that are no longer needed.
#
# ### Notebook-specific guidance
#
# - Keep analysis code reproducible and organized.
# - Use Markdown cells to explain **why** each analysis is being performed and what the result means.
# - Do not leave unexplained output, debugging code, or unused plots in the final version.
# - If requested, export the finished notebook to HTML/PDF in addition to submitting the `.ipynb` file.

# %% [markdown]
# # Setup
#
# Modify the imports as needed for your project. Keep only packages you actually use.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Optional modeling tools; import additional packages only if needed.
from sklearn.model_selection import train_test_split, cross_val_score

DATA_DIR = Path("./data")

pd.set_option("display.max_columns", 100)

# %% [markdown]
# # Update 6
#
# - Accomplishments since the previous update:
#   - ...
# - Approaches you tried that did not work:
#   - ...
# - What you plan to do next:
#   - ...
# - Questions you have about the project:
#   - ...
# - Reference the relevant sections, figures, and tables discussed in this update.

# %% [markdown]
# # Update 5
#
# - Accomplishments since the previous update:
#   - ...
# - Approaches you tried that did not work:
#   - ...
# - What you plan to do next:
#   - ...
# - Questions you have about the project:
#   - ...
# - Reference the relevant sections, figures, and tables discussed in this update.

# %% [markdown]
# # Update 4
#
# - Accomplishments since the previous update:
#   - ...
# - Approaches you tried that did not work:
#   - ...
# - What you plan to do next:
#   - ...
# - Questions you have about the project:
#   - ...
# - Reference the relevant sections, figures, and tables discussed in this update.

# %% [markdown]
# # Update 3
#
# - Accomplishments since the previous update:
#   - ...
# - Approaches you tried that did not work:
#   - ...
# - What you plan to do next:
#   - ...
# - Questions you have about the project:
#   - ...
# - Reference the relevant sections, figures, and tables discussed in this update.

# %% [markdown]
# # Update 2
#
# - Accomplishments since the previous update:
#   - ...
# - Approaches you tried that did not work:
#   - ...
# - What you plan to do next:
#   - ...
# - Questions you have about the project:
#   - ...
# - Reference the relevant sections, figures, and tables discussed in this update.

# %% [markdown]
# # Update 1
#
# - Accomplishments since the previous update:
#   - ...
# - Approaches you tried that did not work:
#   - ...
# - What you plan to do next:
#   - ...
# - Questions you have about the project:
#   - ...
# - Reference the relevant sections, figures, and tables discussed in this update.

# %% [markdown]
# # Executive Summary
#
# Summarize the key points of the project. A concise bulleted list is acceptable.
#
# Include:
#
# - key information about the dataset,
# - major data-cleaning decisions,
# - major findings from EDA,
# - model output/performance,
# - overall conclusions.

# %% [markdown]
# # Abstract
#
# Write **one paragraph** summarizing the nature, findings, and meaning of your data-analysis project.

# %% [markdown]
# # Introduction
#
# Explain the background and motivation for the data-science question — the **why** of the research.
#
# Address:
#
# - What question are you trying to answer?
# - Why is the question important?
# - Where did the data come from?
# - What are the important variables?
# - What additional data would improve the analysis?

# %% [markdown]
# # Data Science Methods
#
# Describe the methods you will apply, for example:
#
# - image processing,
# - time-series analysis,
# - spectral analysis,
# - statistical modeling,
# - machine learning.
#
# Define the critical capabilities required and identify the Python packages you use.

# %%
# Example: list the main packages/methods used in your project.
# Replace this cell with project-specific code or remove it if not needed.

# %% [markdown]
# # Exploratory Data Analysis
#
# ## Explanation of Your Dataset
#
# Address:
#
# - How many observations and variables are there?
# - What are the data types?
# - For categorical variables, how many levels/categories are there?
# - Is the dataset suitable for the proposed analysis?
# - Provide a **data dictionary/codebook** defining variables, units, and structure.

# %%
# Example starter code — replace "your_file.csv" with your actual file.
# df = pd.read_csv(DATA_DIR / "your_file.csv")
# print(df.shape)
# df.info()
# display(df.head())
# display(df.describe(include="all").T)

# %% [markdown]
# ### Data Dictionary / Codebook
#
# Create a table like the following and expand it for your dataset:
#
# | Variable | Description | Type | Units | Valid range/categories | Missing-value meaning |
# |---|---|---|---|---|---|
# | `...` | ... | ... | ... | ... | ... |

# %% [markdown]
# ## Data Cleaning
#
# Explain what you had to do to clean the data.
#
# For each important cleaning decision, explain:
#
# - what problem you found,
# - how you identified it,
# - what you changed,
# - how many observations were affected,
# - whether the choice could bias the analysis.

# %%
# Data-cleaning code here.

# %% [markdown]
# ## Data Visualizations
#
# Use visualizations to investigate the data and communicate findings.
#
# Every final-report figure should have:
#
# - a clear title/caption,
# - readable axes and units,
# - appropriate scales,
# - a discussion in the surrounding Markdown explaining what the figure shows and why it matters.

# %%
# Visualization code here.
# Example:
# fig, ax = plt.subplots(figsize=(8, 5))
# ...
# ax.set_title("Descriptive figure title")
# ax.set_xlabel("...")
# ax.set_ylabel("...")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Variable Correlations
#
# Investigate relationships among variables where scientifically/statistically appropriate.
#
# Possible approaches include:
#
# - pairwise correlation matrices,
# - scatterplot matrices,
# - grouped comparisons,
# - domain-specific association measures.
#
# Do not interpret correlation as causation.

# %%
# Example for numeric variables:
# numeric = df.select_dtypes(include="number")
# corr = numeric.corr()
# display(corr)

# %% [markdown]
# # Statistical Learning: Modeling & Prediction
#
# At minimum, the original DSCI 451 guidance called for one simple linear model or simple logistic model. More advanced courses/projects should use modeling appropriate for the dataset and research question, potentially including machine learning.
#
# Possible components:
#
# - statistical prediction/modeling,
# - model selection,
# - cross-validation,
# - predictive $R^2$ or appropriate classification metrics,
# - interpretation of results,
# - challenging/validating results.
#
# Clearly separate **model fitting** from **model evaluation** and explain how the validation strategy matches the data-generating process.

# %%
# Modeling code here.
# Define X and y, establish a baseline, split/validate appropriately,
# fit the model, evaluate out-of-sample performance, and interpret results.

# %% [markdown]
# # Discussion
#
# Discuss the answers to the data-science questions framed in the Introduction.
#
# Explain:
#
# - what the evidence supports,
# - what it does not support,
# - limitations and uncertainty,
# - alternative explanations,
# - implications of the findings.

# %% [markdown]
# # Conclusions
#
# State the main conclusions clearly and concisely. Tie them directly back to the original project question.

# %% [markdown]
# # Acknowledgments
#
# Acknowledge people, organizations, data providers, funding, or other assistance as appropriate.

# %% [markdown]
# # References
#
# Provide complete citations for datasets, papers, websites, software, and other sources used in the project.
#
# You may use a citation manager/BibTeX workflow or provide properly formatted references manually. Be consistent.
